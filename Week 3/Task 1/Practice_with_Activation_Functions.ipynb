# %% [markdown]
# <a href="https://colab.research.google.com/github/Hassan-zeidan/AAI612_Zeidan_Deep_learning/blob/main/Week%203/Task%201/Practice_with_Activation_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Load MNIST (data)

# %%
import tensorflow as tf
import numpy as np
import time
tf.random.set_seed(42)
np.random.seed(42)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train, x_val = x_train[:-10000], x_train[-10000:]
y_train, y_val = y_train[:-10000], y_train[-10000:]

# %% [markdown]
# ##Two layers with ReLU activation functions and one with softmax

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),

    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),

    tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7728 - loss: 0.7955 - val_accuracy: 0.9468 - val_loss: 0.1934
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9432 - loss: 0.1966 - val_accuracy: 0.9583 - val_loss: 0.1411
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9592 - loss: 0.1379 - val_accuracy: 0.9637 - val_loss: 0.1185
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9684 - loss: 0.1051 - val_accuracy: 0.9688 - val_loss: 0.1052
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9753 - loss: 0.0819 - val_accuracy: 0.9708 - val_loss: 0.0964
# Training time (sec): 12.7
# Best val accuracy: 0.9708

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##four layers with ReLU activation functions and one with softmax

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7641 - loss: 0.8074 - val_accuracy: 0.9519 - val_loss: 0.1696
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9480 - loss: 0.1707 - val_accuracy: 0.9589 - val_loss: 0.1391
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9633 - loss: 0.1219 - val_accuracy: 0.9658 - val_loss: 0.1169
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9722 - loss: 0.0904 - val_accuracy: 0.9678 - val_loss: 0.1058
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9791 - loss: 0.0695 - val_accuracy: 0.9683 - val_loss: 0.1026
# Training time (sec): 14.14
# Best val accuracy: 0.9683

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##Two layers with tanh activation functions and one with softmax

# %%
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="tanh"),
    tf.keras.layers.Dense(128, activation="tanh"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7842 - loss: 0.7452 - val_accuracy: 0.9321 - val_loss: 0.2346
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9296 - loss: 0.2399 - val_accuracy: 0.9509 - val_loss: 0.1745
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9487 - loss: 0.1741 - val_accuracy: 0.9590 - val_loss: 0.1422
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9618 - loss: 0.1334 - val_accuracy: 0.9639 - val_loss: 0.1222
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9693 - loss: 0.1052 - val_accuracy: 0.9667 - val_loss: 0.1091
# Training time (sec): 10.9
# Best val accuracy: 0.9667

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##Four layers with tanh activation functions and one with softmax

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="tanh"),
    tf.keras.layers.Dense(128, activation="tanh"),
    tf.keras.layers.Dense(128, activation="tanh"),
    tf.keras.layers.Dense(128, activation="tanh"),
    tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8028 - loss: 0.6612 - val_accuracy: 0.9425 - val_loss: 0.1991
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9411 - loss: 0.2019 - val_accuracy: 0.9576 - val_loss: 0.1432
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9575 - loss: 0.1419 - val_accuracy: 0.9620 - val_loss: 0.1255
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9670 - loss: 0.1096 - val_accuracy: 0.9647 - val_loss: 0.1120
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9738 - loss: 0.0860 - val_accuracy: 0.9674 - val_loss: 0.1027
# Training time (sec): 13.46
# Best val accuracy: 0.9674

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##Two layers with Sigmoid activation functions and one with softmax

# %%
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="sigmoid"),
    tf.keras.layers.Dense(128, activation="sigmoid"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5696 - loss: 1.6259 - val_accuracy: 0.8980 - val_loss: 0.4257
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8967 - loss: 0.4016 - val_accuracy: 0.9236 - val_loss: 0.2731
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9209 - loss: 0.2822 - val_accuracy: 0.9356 - val_loss: 0.2243
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9333 - loss: 0.2322 - val_accuracy: 0.9445 - val_loss: 0.1948
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9421 - loss: 0.1987 - val_accuracy: 0.9515 - val_loss: 0.1734
# Training time (sec): 11.15
# Best val accuracy: 0.9515

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##four layers with Sigmoid activation functions and one with softmax

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="sigmoid"),
    tf.keras.layers.Dense(128, activation="sigmoid"),
    tf.keras.layers.Dense(128, activation="sigmoid"),
    tf.keras.layers.Dense(128, activation="sigmoid"),
    tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.2630 - loss: 2.1084 - val_accuracy: 0.8433 - val_loss: 0.6641
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8638 - loss: 0.5302 - val_accuracy: 0.9177 - val_loss: 0.2973
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9171 - loss: 0.2941 - val_accuracy: 0.9346 - val_loss: 0.2244
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9369 - loss: 0.2234 - val_accuracy: 0.9478 - val_loss: 0.1812
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9483 - loss: 0.1799 - val_accuracy: 0.9550 - val_loss: 0.1539
# Training time (sec): 14.8
# Best val accuracy: 0.955

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ## Leaky ReLU

# %%
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),

    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.01),

    tf.keras.layers.Dense(128),
    tf.keras.layers.LeakyReLU(alpha=0.01),

    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7651 - loss: 0.8212 - val_accuracy: 0.9461 - val_loss: 0.1904
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9442 - loss: 0.1925 - val_accuracy: 0.9585 - val_loss: 0.1416
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9597 - loss: 0.1350 - val_accuracy: 0.9653 - val_loss: 0.1197
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9689 - loss: 0.1026 - val_accuracy: 0.9694 - val_loss: 0.1070
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9764 - loss: 0.0802 - val_accuracy: 0.9706 - val_loss: 0.0981
# Training time (sec): 12.23
# Best val accuracy: 0.9706

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##ELU

# %%
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),

    tf.keras.layers.Dense(128),
    tf.keras.layers.ELU(alpha=1.0),

    tf.keras.layers.Dense(128),
    tf.keras.layers.ELU(alpha=1.0),

    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7912 - loss: 0.7153 - val_accuracy: 0.9314 - val_loss: 0.2367
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9300 - loss: 0.2420 - val_accuracy: 0.9503 - val_loss: 0.1735
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9488 - loss: 0.1742 - val_accuracy: 0.9581 - val_loss: 0.1391
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9603 - loss: 0.1338 - val_accuracy: 0.9652 - val_loss: 0.1168
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9683 - loss: 0.1062 - val_accuracy: 0.9697 - val_loss: 0.1029
# Training time (sec): 11.0
# Best val accuracy: 0.9697

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##Swish (SiLU)

# %%
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),

    tf.keras.layers.Dense(128),
    tf.keras.layers.Activation(tf.nn.swish),

    tf.keras.layers.Dense(128),
    tf.keras.layers.Activation(tf.nn.swish),

    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7554 - loss: 0.8645 - val_accuracy: 0.9411 - val_loss: 0.2103
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9381 - loss: 0.2143 - val_accuracy: 0.9564 - val_loss: 0.1523
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9566 - loss: 0.1480 - val_accuracy: 0.9658 - val_loss: 0.1241
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9673 - loss: 0.1123 - val_accuracy: 0.9693 - val_loss: 0.1077
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9736 - loss: 0.0892 - val_accuracy: 0.9717 - val_loss: 0.0972
# Training time (sec): 12.11
# Best val accuracy: 0.9717

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##GELU

# %%
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),

    tf.keras.layers.Dense(128),
    tf.keras.layers.Activation(tf.nn.gelu),

    tf.keras.layers.Dense(128),
    tf.keras.layers.Activation(tf.nn.gelu),

    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ##train and measure time + best validation

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7575 - loss: 0.8249 - val_accuracy: 0.9461 - val_loss: 0.1944
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9425 - loss: 0.1966 - val_accuracy: 0.9609 - val_loss: 0.1401
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9603 - loss: 0.1354 - val_accuracy: 0.9653 - val_loss: 0.1182
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9699 - loss: 0.1021 - val_accuracy: 0.9679 - val_loss: 0.1055
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9763 - loss: 0.0797 - val_accuracy: 0.9708 - val_loss: 0.0972
# Training time (sec): 13.66
# Best val accuracy: 0.9708

# %% [markdown]
# .
#
# .
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ________________________________________________________________________________
#
#
# .
#
# .

# %% [markdown]
# ##GELU with 4 hidden

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),

    tf.keras.layers.Dense(128), tf.keras.layers.Activation(tf.nn.gelu),
    tf.keras.layers.Dense(128), tf.keras.layers.Activation(tf.nn.gelu),
    tf.keras.layers.Dense(128), tf.keras.layers.Activation(tf.nn.gelu),
    tf.keras.layers.Dense(128), tf.keras.layers.Activation(tf.nn.gelu),

    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
start = time.time()

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=5,
    batch_size=256,
    verbose=1
)

end = time.time()

print("Training time (sec):", round(end - start, 2))
print("Best val accuracy:", round(max(history.history["val_accuracy"]), 4))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7387 - loss: 0.8701 - val_accuracy: 0.9477 - val_loss: 0.1742
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9497 - loss: 0.1696 - val_accuracy: 0.9628 - val_loss: 0.1243
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9651 - loss: 0.1146 - val_accuracy: 0.9656 - val_loss: 0.1144
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9734 - loss: 0.0862 - val_accuracy: 0.9693 - val_loss: 0.1047
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9800 - loss: 0.0657 - val_accuracy: 0.9696 - val_loss: 0.1046
# Training time (sec): 18.77
# Best val accuracy: 0.9696
