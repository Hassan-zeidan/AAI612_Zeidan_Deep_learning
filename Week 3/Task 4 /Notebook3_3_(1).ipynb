# %% [markdown]
# <a href="https://colab.research.google.com/github/Hassan-zeidan/AAI612_Zeidan_Deep_learning/blob/main/Week%203/Task%204%20/Notebook3_3_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI612: Deep Learning & its Applications
#
# *Notebook 3.3: Practice with HuggingFace*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI612/blob/main/Week3/Notebook3.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Experiment with Hugging Face Transformers

# %%
text_0 = """Having served on the COVID Vaccine Development committee at Moderna, USA, \
    Dr. Nader was involved in the fight against the pandemic of the century. As \
    the race was on to develop a vaccine – the ultimate defense against a virus \
    of which little was known – what helped to expedite the process at the \
    pharmaceutical and biotechnology company was the availability of the \
    technology – messenger RNA – which had been 10 years in the making.\
    The development of vaccines in record time encapsulates the prerequisites \
    for discovery: research, technology, anticipation and inquiring minds, skills \
    that should be fostered in education."""

# %% [markdown]
# ### Text Completion

# %% [markdown]
# Once you execute the below code, notice in the score in the output.  The highest the score, the higher the probability of that output being selected!

# %%
from transformers import pipeline

# specifying the pipeline
bert_unmasker = pipeline('fill-mask', model="bert-base-uncased")
text = "I have to wake up in the morning and [MASK] a doctor"
result = bert_unmasker(text)
for r in result:
    print(r)
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: bert-base-uncased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.weight | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# {'score': 0.6457526087760925, 'token': 2156, 'token_str': 'see', 'sequence': 'i have to wake up in the morning and see a doctor'}
# {'score': 0.17833702266216278, 'token': 2655, 'token_str': 'call', 'sequence': 'i have to wake up in the morning and call a doctor'}
# {'score': 0.07508129626512527, 'token': 2424, 'token_str': 'find', 'sequence': 'i have to wake up in the morning and find a doctor'}
# {'score': 0.05682728812098503, 'token': 2131, 'token_str': 'get', 'sequence': 'i have to wake up in the morning and get a doctor'}
# {'score': 0.006895779632031918, 'token': 2022, 'token_str': 'be', 'sequence': 'i have to wake up in the morning and be a doctor'}

# %% [markdown]
# ### Text Classification

# %% [markdown]
# The below will be classified the above text as positive.  Can you change that?

# %%
#hide_output
from transformers import pipeline

classifier = pipeline("text-classification")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
import pandas as pd

outputs = classifier(text_0)
pd.DataFrame(outputs)
# Out:
#       label     score
# 0  POSITIVE  0.998032

# %%
sent_text = "I am unhappy with the service. It was frustrating and disappointing."
outputs = classifier(sent_text)
pd.DataFrame(outputs)
# Out:
#       label     score
# 0  NEGATIVE  0.999738

# %% [markdown]
# ### Named Entity Recognition

# %% [markdown]
# NER involves detecting and categorizing information in text known as named entities. Named entities refer to the key subjects of a piece of text, such as names, locations, companies, events and products, as well as themes, topics, times, monetary values and percentages.

# %%
ner_tagger = pipeline("ner", aggregation_strategy="simple")
outputs = ner_tagger(text_0)
pd.DataFrame(outputs)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   entity_group     score                word  start  end
# 0          ORG  0.910735             COVID V     21   28
# 1          ORG  0.519498  ##cine Development     30   46
# 2          ORG  0.613607             Moderna     60   67
# 3          LOC  0.999528                 USA     69   72
# 4          PER  0.995201               Nader     82   87

# %% [markdown]
# ### Question Answering

# %%
reader = pipeline("question-answering")
question = "What was Dr. Nader involved in?"
outputs = reader(question=question, context=text_0)
pd.DataFrame([outputs])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
#       score  start  end                                     answer
# 0  0.497019    108  149  fight against the pandemic of the century

# %% [markdown]
# ### Summarization

# %%
summarizer = pipeline("image-text-to-text", model="facebook/bart-large-cnn")
outputs = summarizer(text_0, max_length=45)
print(outputs[0])
# Out:
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/511 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3767616135.py in <cell line: 0>()
# ----> 1 summarizer = pipeline("image-text-to-text", model="facebook/bart-large-cnn")
#       2 outputs = summarizer(text_0, max_length=45)
#       3 print(outputs[0])
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1004         except Exception as e:
#    1005             if load_processor:
# -> 1006                 raise e
#    1007             else:
#    1008                 processor = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     997                 processor = AutoProcessor.from_pretrained(processor, _from_pipeline=task, **hub_kwargs, **model_kwargs)
#     998                 if not isinstance(processor, ProcessorMixin):
# --> 999                     raise TypeError(
#    1000                         "Processor was loaded, but it is not an instance of `ProcessorMixin`. "
#    1001                         f"Got type `{type(processor)}` instead. Please check that you specified "
#
# TypeError: Processor was loaded, but it is not an instance of `ProcessorMixin`. Got type `<class 'transformers.models.roberta.tokenization_roberta.RobertaTokenizer'>` instead. Please check that you specified correct pipeline task for the model and model has processor implemented and saved.

# %% [markdown]
# ### Translation

# %% [markdown]
# The below will use a German translation model.  Can you change this to French?  Google will be your best friend in this task :-)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr")

inputs = tokenizer(text_0, return_tensors="pt", padding=True, truncation=True)
outputs = model.generate(**inputs)
translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(translated_text)
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Après avoir siégé au comité de développement des vaccins COVID à Moderna, aux États-Unis, le Dr Nader a participé à la lutte contre la pandémie du siècle. Alors que la course était en cours pour développer un vaccin – la défense ultime contre un virus dont on ne savait pas grand-chose – ce qui a contribué à accélérer le processus à la société pharmaceutique et de biotechnologie était la disponibilité de la technologie – l'ARN messager – qui avait été 10 ans en cours de fabrication.

# %% [markdown]
# ### Text Generation

# %%
#hide
from transformers import set_seed
set_seed(42) # Set the seed to get reproducible results

# %%
generator = pipeline("text-generation")
response = "Dear Dr. Nader, Thank you for working on the vaccine."
prompt = text_0 + "\n\nResponse to the story:\n" + response
outputs = generator(prompt, max_length=500)
print(outputs[0]['generated_text'])
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: openai-community/gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Having served on the COVID Vaccine Development committee at Moderna, USA,     Dr. Nader was involved in the fight against the pandemic of the century. As     the race was on to develop a vaccine – the ultimate defense against a virus     of which little was known – what helped to expedite the process at the     pharmaceutical and biotechnology company was the availability of the     technology – messenger RNA – which had been 10 years in the making.    The development of vaccines in record time encapsulates the prerequisites     for discovery: research, technology, anticipation and inquiring minds, skills     that should be fostered in education.
#
# Response to the story:
# Dear Dr. Nader, Thank you for working on the vaccine. I would like to thank you for your involvement in our study. Dr. Nader would like to thank you for your expertise. I wanted to acknowledge that you are a brilliant researcher. I had a long career as a researcher, a scientist, and a consultant to the pharmaceutical industry. As a consultant, I have developed the vaccine by hand and have provided guidance to the scientists involved. I have also been involved in many other scientific research projects, from the discovery of      diseases to the development of new technologies and vaccines that have been applied in the field of vaccine science.
#
# From my point of view, I am the only person in the world who has been able to explain the importance of the vaccine to the scientific community. I have written to you to ask you to give me your time and support, to encourage you to do something important for the vaccine. I have asked you to help me develop the vaccine with the help of the following individuals (in alphabetical order): Dr. J.H. Nader, Director of the Vaccine Development Committee at Moderna, USA
#
# Dr. Alan H. Nader, Director of the Vaccine Development Committee at Modern
